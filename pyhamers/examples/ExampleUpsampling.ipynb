# %%
"""
Script to test the upsampling.
"""

from pyhamers.readers import samrai_reader
from pyhamers.upsampling import Lagrange_upsampler
import numpy

from matplotlib import pyplot as plt

# %%
"""
Set the path of the data directory for the data reader.
"""

data_reader = samrai_reader.SamraiDataReader('../tests/test_data_samrai_AMR')
data_order = data_reader.data_order

# %%
"""
Read the density data from all levels.
"""

steps = data_reader.steps

data_reader.step = steps[-1]

data_rho, = data_reader.readData('density')

# %%
"""
Upsample the data.
"""

r = numpy.array([3, 3])

upsampler_constant     = Lagrange_upsampler.LagrangeUpsampler(method='constant', data_order=data_order)
upsampler_second_order = Lagrange_upsampler.LagrangeUpsampler(method='second_order', data_order=data_order)
upsampler_fourth_order = Lagrange_upsampler.LagrangeUpsampler(method='fourth_order', data_order=data_order)
upsampler_sixth_order  = Lagrange_upsampler.LagrangeUpsampler(method='sixth_order', data_order=data_order)

data_upsampled_1 = upsampler_constant.upsample(data_rho, r)
data_upsampled_2 = upsampler_second_order.upsample(data_rho, r)
data_upsampled_3 = upsampler_fourth_order.upsample(data_rho, r)
data_upsampled_4 = upsampler_sixth_order.upsample(data_rho, r)

# %%
"""
Plot the original data.
"""

data_masked = numpy.ma.masked_where(numpy.isnan(data_rho), data_rho)

plt.figure()
plt.pcolormesh(data_masked[:,:].T, vmin=-1.0, vmax=12.0)
ax = plt.gca()
ax.set_aspect('equal', adjustable='box')
plt.xlabel('x')
plt.ylabel('y')
plt.colorbar()
plt.show()

# %%
"""
Plot the first upsampled data.
"""

data_masked_1 = numpy.ma.masked_where(numpy.isnan(data_upsampled_1), data_upsampled_1)

plt.figure()
plt.pcolormesh(data_masked_1[:,:].T, vmin=-1.0, vmax=12.0)
ax = plt.gca()
ax.set_aspect('equal', adjustable='box')
plt.xlabel('x')
plt.ylabel('y')
plt.colorbar()
plt.show()

# %%
"""
Plot the second upsampled data.
"""

data_masked_2 = numpy.ma.masked_where(numpy.isnan(data_upsampled_2), data_upsampled_2)

plt.figure()
plt.pcolormesh(data_masked_2[:,:].T, vmin=-1.0, vmax=12.0)
ax = plt.gca()
ax.set_aspect('equal', adjustable='box')
plt.xlabel('x')
plt.ylabel('y')
plt.colorbar()
plt.show()

# %%
"""
Plot the third upsampled data.
"""

data_masked_3 = numpy.ma.masked_where(numpy.isnan(data_upsampled_3), data_upsampled_3)

plt.figure()
plt.pcolormesh(data_masked_3[:,:].T, vmin=-1.0, vmax=12.0)
ax = plt.gca()
ax.set_aspect('equal', adjustable='box')
plt.xlabel('x')
plt.ylabel('y')
plt.colorbar()
plt.show()

# %%
"""
Plot the fourth upsampled data.
"""

data_masked_4 = numpy.ma.masked_where(numpy.isnan(data_upsampled_4), data_upsampled_4)

plt.figure()
plt.pcolormesh(data_masked_4[:,:].T, vmin=-1.0, vmax=12.0)
ax = plt.gca()
ax.set_aspect('equal', adjustable='box')
plt.xlabel('x')
plt.ylabel('y')
plt.colorbar()
plt.show()
